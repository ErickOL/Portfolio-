# %% [markdown]
# <div style="background-color:#084d6e ; border-radius:2px; border:#000000 solid; padding: 15px; font-size:100%; text-align:center">
#     <h1 align="center" style="color:#ffffff;"><b>SISTEMA DE DADOS BANCÁRIOS🏦💰💳</b></h1>
# </div>

# %%
# %%html
# <marquee style='width: 100%; color: #008080 ;'><b> CIENTISTA DE DADOS !</b></marquee>

# %% [markdown]
# <center><div style="font-size: 30px; font-weight: bold;"><span style="background-color: lightblue; color: #084d6e;">Análise Exploratória de Dados</span></div></center>

# %% [markdown]
# A *Análise Exploratória de Dados* $(AED)$ é uma etapa fundamental no processo de análise de dados, que envolve a *exploração* e a *compreensão dos dados disponíveis*.
#
# - Seu objetivo principal é nos ajudar a entendermos melhor do conjunto de dados com o qual estão trabalhando, identificando *padrões, tendências, relações e anomalias nos dados*;
#
#   - Também, é nessa fase onde levantamos hipóteses sobre os dados que visam atender o problema de Negócio.

# %% [markdown]
# <a id="1"></a>
# ## <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#008080;overflow:hidden">1° | Problema de Negócio</div>

# %% [markdown]
# O conjunto de dados contem uma amostra de dados de clientes de um determinado banco.

# %% [markdown]
# <a id="1.1"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0d6273 ; background-color: #ffffff;"><b>1.1 | Objetivo</b> Principal

# %% [markdown]
# - Entender e explorar os dados para que possamos extrair insights que auxiliem o time
# estratégico na tomada de decisão, verifique também possíveis associações entre variáveis.

# %% [markdown]
# <a id="1.2"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0d6273; background-color: #ffffff;"><b>1.2 | Descrição das</b> Varáveis

# %% [markdown]
# - **Cliente** $→$ Identificador do cliente.
# - **Sexo** $→$ É o sexo da Pessoa (*Masculino = M   e     Feminino = F*)
# - **Idade** $→$ Idade do cliente, em anos completos.
# - **Empresa** $→$ Tipo da empresa em que trabalha: Pública, Privada ou Autônomo
# - **Salário** $→$ Salário declarado pelo cliente na abertura da conta, em reais.
# - **Saldo_cc** $→$ Saldo em conta corrente, em reais.
# - **Saldo_poupança** $→$ Saldo em poupança, em reais.
# - **Saldo_investimento** $→$ Saldo em investimentos, em reais.
# - **Devedor_cartao** $→$ Valor em atraso no cartão de crédito, em reais.
# - **Inadimplente** $→$ Indica se o cliente é considerado inadimplente ou não
#
#   - $1→$ Indica que o cliente é inadimplente;
#   - $0→$ Indica que o cliente não é inadimplente.

# %% [markdown]
# <a id="2"></a>
# ## <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#008080;overflow:hidden">2° | Análise Exploratória dos Dados</div>

# %% [markdown]
# <a id="2.1"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #006b80; background-color: #ffffff;"><b>2.1 | Importando as</b> Bibliotecas

# %%
# Importando as Bibliotecas
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np 
import statistics as stc
from scipy import stats 
from statsmodels.graphics.mosaicplot import mosaic # permite criar gráficos de mosaico (mosaic plots)


# Serve para Ignorando alertas idesejados
import warnings
warnings.filterwarnings("ignore")

# Serve para Manter os gráficos nesse mesmo Notebook
# %matplotlib inline

# Define o estilo do gráfico seaborn
sns.set(style="whitegrid")

# %% [markdown]
# <a id="2.1"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0d6273; background-color: #ffffff;"><b>2.2 | Carregando e Visualizando os</b> Dados

# %%
# Carregando os Dados
dados_banco = pd.read_csv('clientes_banco.csv')

# %% [markdown]
# <a id="2.3"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0d6273; background-color: #ffffff;"><b>2.3 | Algumas </b> Informações dos Dados!

# %% [markdown]
# - Visualizando todos os dados

# %%
dados_banco
# Out:
#       Cliente Sexo  Idade   Empresa  Salario  Saldo_cc  Saldo_poupança  \
# 0       75928    M     32   Privada  5719.00    933.79             0.0
# 1       52921    F     28   Privada  5064.00    628.37             0.0
# 2        8387    F     24  Autônomo  4739.00    889.18             0.0
# 3       54522    M     30   Pública  5215.00   1141.47             0.0
# 4       45397    M     30  Autônomo  5215.56    520.70             0.0
# ...       ...  ...    ...       ...      ...       ...             ...
# 9995    33487    F     31   Pública  5016.00    498.96             0.0
# 9996    71360    M     29   Pública  5329.00   1142.82             0.0
# 9997    92455    M     34   Privada  5581.00    885.34             0.0
# 9998    61296    F     28   Privada  5061.00    660.74             0.0
# 9999    52862    M     33  Autônomo  5519.00   1147.71             0.0
#
#       Saldo_investimento  Devedor_cartao  Inadimplente
# 0                    0.0         6023.68             0
# ...

# %% [markdown]
# - Visualizando as 5 primeiras e últimas linhas da base dados.

# %%
# Visualizando as 5 últimas linhas do DataFrame
dados_banco .head()
# Out:
#    Cliente Sexo  Idade   Empresa  Salario  Saldo_cc  Saldo_poupança  \
# 0    75928    M     32   Privada  5719.00    933.79             0.0
# 1    52921    F     28   Privada  5064.00    628.37             0.0
# 2     8387    F     24  Autônomo  4739.00    889.18             0.0
# 3    54522    M     30   Pública  5215.00   1141.47             0.0
# 4    45397    M     30  Autônomo  5215.56    520.70             0.0
#
#    Saldo_investimento  Devedor_cartao  Inadimplente
# 0                 0.0         6023.68             0
# 1                 0.0         1578.24             0
# 2                 0.0         2578.70             0
# 3                 0.0         4348.96             0
# 4                 0.0         1516.78             1

# %%
# Visualizando as 5 últimas linhas do DataFrame
dados_banco.tail()

# %% [markdown]
# - Visualizando com Background

# %%
styled_df = dados_banco.head().style

# Defina a cor de fundo, a cor do texto e a borda de todo o DataFrame
styled_df.set_properties(**{"background-color": "#254E58", "color": "#e9c46a", "border": "1.5px solid black"})

# Modificando a cor de fundo dos cabeçalhos da tabela
styled_df.set_table_styles([
    {"selector": "th", "props": [("color", 'white'), ("background-color", "#333333")]}
])
# Out:
# <style type="text/css">
# #T_811e1 th {
#   color: white;
#   background-color: #333333;
# }
# ...

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.3.1 |
# Nome das Colunas</b></span>

# %%
# Verificando o nome das colunas
dados_banco.columns
# Out:
# Index(['Cliente', 'Sexo', 'Idade', 'Empresa', 'Salario', 'Saldo_cc',
#        'Saldo_poupança', 'Saldo_investimento', 'Devedor_cartao',
#        'Inadimplente'],
#       dtype='object')

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.3.2 |
# Verificando o Números de Linhas e Colunas</b></span>

# %%
# Verificar o tamanho da base de dados "(Linhas, Colunas")
dados_banco.shape
# Out:
# (10000, 10)

# %%
# Outra forma de Verificar o Tamanho da Base de Dados
linhas , colunas =  dados_banco.shape
print("Número de Linhas : {} \nNúmero de Colunas : {}".format(linhas , colunas))
# Out:
# Número de Linhas : 10000
# Número de Colunas : 10

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.3.3 | Informações Básicas</b></span>

# %% [markdown]
# - Verificando o tipo de dados

# %%
# Verificando o tipo de dados
dados_banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cliente             10000 non-null  int64
#  1   Sexo                10000 non-null  object
#  2   Idade               10000 non-null  int64
#  3   Empresa             10000 non-null  object
#  4   Salario             10000 non-null  float64
#  5   Saldo_cc            10000 non-null  float64
#  6   Saldo_poupança      10000 non-null  float64
#  7   Saldo_investimento  10000 non-null  float64
#  8   Devedor_cartao      10000 non-null  float64
#  9   Inadimplente        10000 non-null  int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 781.4+ KB

# %%
# Outra forma de Verificar o tipo de dados
dados_banco.dtypes
# Out:
# Cliente                 int64
# Sexo                   object
# Idade                   int64
# Empresa                object
# Salario               float64
# Saldo_cc              float64
# Saldo_poupança        float64
# Saldo_investimento    float64
# Devedor_cartao        float64
# Inadimplente            int64
# dtype: object

# %% [markdown]
# - Verificando a quantidade de itens

# %%
# Verificando a quantidade de Registros
dados_banco.count()
# Out:
# Cliente               10000
# Sexo                  10000
# Idade                 10000
# Empresa               10000
# Salario               10000
# Saldo_cc              10000
# Saldo_poupança        10000
# Saldo_investimento    10000
# Devedor_cartao        10000
# Inadimplente          10000
# dtype: int64

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.3.4 | Verificando Valores Ausentes/Nulos</b></span>

# %% [markdown]
# - Verificando se há valores ausentes usando o **isna**

# %%
# Verificando se há valores ausentes
dados_banco.isna().sum()
# Out:
# Cliente               0
# Sexo                  0
# Idade                 0
# Empresa               0
# Salario               0
# Saldo_cc              0
# Saldo_poupança        0
# Saldo_investimento    0
# Devedor_cartao        0
# Inadimplente          0
# dtype: int64

# %%
# Verificando se há valores ausentes
dados_banco.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# - Verificando se há valores ausentes usando o **isnull**

# %%
# Verificando se há valores ausentes
dados_banco.isnull().sum()
# Out:
# Cliente               0
# Sexo                  0
# Idade                 0
# Empresa               0
# Salario               0
# Saldo_cc              0
# Saldo_poupança        0
# Saldo_investimento    0
# Devedor_cartao        0
# Inadimplente          0
# dtype: int64

# %%
# Verificando se há valores ausentes
dados_banco.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.3.5 | Verificando Valores Duplicados</b></span>

# %%
# Verificando se há valores duplicados
dados_banco.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
# Verificando se há valores duplicados
dados_banco.duplicated().sum()
# Out:
# 0

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.3.6 |
# Verificando Valores Únicos em Colunas Categóricas</b></span>

# %% [markdown]
# - Variável **Sexo**

# %%
# Verificando os valores únicos em uma coluna Específica
dados_banco.Sexo.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
# Outra forma de Verificar os valores únicos em uma coluna Específica
dados_banco['Sexo'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# - Variável **Empresa**

# %%
# Vericando os valores Únicos
dados_banco['Empresa'].unique()
# Out:
# array(['Privada', 'Autônomo', 'Pública'], dtype=object)

# %% [markdown]
# <a id="2.4"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0d6273; background-color: #ffffff;"><b>2.4 | Analisando a Frequência </b> dos dados Categoricos

# %% [markdown]
# #### Principais Elementos mostrados nessa análise
#
# - $unique →$  Indica a quantidade de observações únicas;
#
# - $top →$ Indica qual é o rotulo mais frequente;
#
# - $freq →$ Indica a frequência que cada rotulo aparece ou ocorre.

# %%
# Verificando a distribuição dos dados categoricos
dados_banco.select_dtypes(include= 'object').describe() # OU df.describe(include = 'O')
# Out:
#          Sexo  Empresa
# count   10000    10000
# unique      2        3
# top         M  Privada
# freq     5769     6103

# %%
# Outra forma de Verificar a distribuição dos dados categoricos
dados_banco.describe(include = 'O')
# Out:
#          Sexo  Empresa
# count   10000    10000
# unique      2        3
# top         M  Privada
# freq     5769     6103

# %% [markdown]
# <a id="2.4"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0d6273; background-color: #ffffff;"><b>2.5 | Estatística Descritiva </b> → Análise Matemática

# %% [markdown]
# - *Essa análise só faz sentido para variáveis numericas*

# %% [markdown]
# #### Principais Elementos mostrados nessa análise
#
# - $count →$ *Quantidade de registros*
#
# - $mean →$  *Valor mediano/médio*, ou seja, é a **Média**
#
# - $std →$  *Desvio Padrão*
#
# - $min →$ *Valor mínimo*
#
# - $25$% $→$ *Primeiro Quartil* $(Q_1)$
#
# - $50$% $→$ *Segundo Quartil* $(Q_2)$ que também representa a **Mediana**
#
# - $75$% $→$ *Terceiro Quartil* $(Q_3)$
#
# - $max →$  *Valor máximo*

# %%
# Análise matematica - ESTATISTICA DESCRITIVA
dados_banco.describe()
# Out:
#             Cliente         Idade       Salario      Saldo_cc  Saldo_poupança  \
# count  10000.000000  10000.000000  10000.000000  10000.000000    10000.000000
# mean   49897.977700     31.801900   5482.880238    773.441611     2224.517679
# std    28829.815505      2.931913    393.779438    246.932963     5668.740769
# min        6.000000     21.000000   4325.720000   -280.670000        0.000000
# 25%    25067.000000     30.000000   5207.540000    599.425000        0.000000
# 50%    49836.000000     32.000000   5498.780000    766.000000        0.000000
# 75%    74699.250000     34.000000   5738.220000    941.470000        0.000000
# max    99993.000000     50.000000   8582.000000   2007.260000    23336.420000
#
#        Saldo_investimento  Devedor_cartao  Inadimplente
# count        10000.000000    10000.000000  10000.000000
# mean          1476.939508     2737.210731      0.246100
# std           3920.049185     1994.877093      0.430759
# ...

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>3.4.1 | Visualizando a Estatística Descritiva com um Display</b></span>

# %%
# Visualizando a "Estatística Descritiva" colocando Background

styled_df = dados_banco.describe().style \
    .set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#254E58'), ('color', 'white'), ('font-weight', 'bold'), ('text-align', 'left'), ('padding', '8px')]},
        {'selector': 'td', 'props': [('padding', '8px')]}
    ]) \
    .set_properties(**{'font-size': '14px', 'background-color': '#F5F5F5', 'border-collapse': 'collapse', 'margin': '10px'})

styled_df
# Out:
# <style type="text/css">
# #T_5c5df th {
#   background-color: #254E58;
#   color: white;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_5c5df td {
#   padding: 8px;
# }
# ...

# %% [markdown]
# <a id="2.5"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0d6273; background-color: #ffffff;"><b>2.6 | Cálculando as Medidas Resumo

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.5.1 | Cálculando a Média, Mediana e o Desvio Padrão</b></span>

# %%
# Média
dados_banco['Idade'].mean()
# Out:
# 31.8019

# %%
#Outra forma de calcular a media
dados_banco.Idade.mean()
# Out:
# 31.8019

# %%
# Mediana
dados_banco['Idade'].median()
# Out:
# 32.0

# %%
# Desvio-padrão
dados_banco['Idade'].std()
# Out:
# 2.9319133687065135

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.5.2 | Média de idade por Sexo</b></span>

# %%
# Média de idade por sexo
dados_banco.groupby('Sexo')['Idade'].mean()
# Out:
# Sexo
# F    30.130466
# M    33.027734
# Name: Idade, dtype: float64

# %% [markdown]
# **Conclusão** 👇🏽👇👇🏽
#
# - A média de idade nos dados é $31.8$ anos, a mediana é $32$ anos. O desvio-padrão da idade na base de dados geral é $2.93$ anos.
#
# - Entre mulheres, a média de idade é $30.1$ anos e entre homens é $33$ anos.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.5.3 | Cálculando a Moda para Empresa</b></span>

# %% [markdown]
# - Lembre-se que a mode só faz sentido para variáveis categóricas

# %%
# Moda - para a Empresa
stc.mode(dados_banco['Empresa'])
# Out:
# 'Privada'

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - Na base de dados, o tipo de empresa mais comum é a empresa $Privada$.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.5.4 | Média de idade por Empresa</b></span>

# %%
# Média de idade por por empresa
dados_banco.groupby('Empresa')['Idade'].mean()
# Out:
# Empresa
# Autônomo    29.163787
# Privada     32.867115
# Pública     30.706531
# Name: Idade, dtype: float64

# %% [markdown]
# **Conclusão** 👇🏽👇👇🏽
#
# - A média de idade entre os clientes autônomos é de $29.2$ anos, entre clientes que trabalham em empresas privadas é $32.9$ anos e para clientes que trabalham em empresas públicas é $30.7$ anos.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.5.5 | Média de Salário por Sexo</b></span>

# %%
# Média de salário por sexo
dados_banco.groupby('Sexo')['Salario'].mean()
# Out:
# Sexo
# F    5223.337707
# M    5673.229423
# Name: Salario, dtype: float64

# %% [markdown]
# **Conclusão** 👇🏽👇👇🏽
#
# - Pode se observar que os homens em média ganham mais que as mulheres. Temos uma diferença aproximadamente de $450$ reais que o homens ganhas a mais que as mulheres.

# %% [markdown]
# <a id="2.5"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0d6273; background-color: #ffffff;"><b>2.7 | Tabela de Frequências </b> Absolutas e Relativas

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.5.1 | Tabela de frequências Absolutas</b></span>

# %%
# Tabela de frequências absolutas
tab_freq_abs = pd.crosstab(index=dados_banco['Empresa'], columns='count')
# Visualizando
tab_freq_abs
# Out:
# col_0     count
# Empresa
# Autônomo   1447
# Privada    6103
# Pública    2450

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.5.2 | Tabela de frequências Relativas</b></span>

# %%
# Criando a Tabela
tab_fre_rel = pd.crosstab(index=dados_banco['Empresa'], columns='count')

# Multiplique a tabela por 100
tab_porcentagem = (tab_fre_rel / tab_fre_rel.sum()) * 100

# Visualizando
tab_porcentagem
# Out:
# col_0     count
# Empresa
# Autônomo  14.47
# Privada   61.03
# Pública   24.50

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - Na base de dados, cerca de $61$% dos clientes trabalham em empresas privadas, $24$% em empresas públicas e $14$% são autônomos.

# %% [markdown]
# <a id="2.6"></a>
# <h4 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0d6273; background-color: #ffffff;"><b>2.8 | Visualização </b>de Dados

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.1 | Tabela de dupla entrada</b></span>

# %%
# Tabela de dupla entrada
tabela_dupla = pd.crosstab(index=dados_banco['Empresa'], columns=dados_banco['Sexo'])

# Visualizando
tabela_dupla
# Out:
# Sexo         F     M
# Empresa
# Autônomo   875   572
# Privada   2047  4056
# Pública   1309  1141

# %%
# Visualização Gráfica
tabela_dupla.plot.bar()
plt.legend(title='Sexo')
plt.show();

# %%
# Visualização Gráfica
tabela_dupla.plot.bar(stacked=True)
plt.legend(title='Sexo')
plt.show();

# %% [markdown]
# - Visualização Gráfica em forma de Mosaico

# %%
mosaic(dados_banco, ['Empresa','Sexo']);

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.3 | Distribuição da Idade </b></span>

# %%
sns.distplot(dados_banco['Idade'], bins=10);

# %%
# Gráfico: Distribuição de Idade dos Clientes
plt.figure(figsize=(8, 6))
sns.histplot(dados_banco['Idade'], bins=30)
plt.title('Distribuição de Idade dos Clientes')
plt.show();

# %%
# Gráfico: Distribuição de Idade dos Clientes
plt.figure(figsize=(8, 6))
sns.histplot(dados_banco['Idade'], bins=30, kde=True)
plt.title('Distribuição de Idade dos Clientes')
plt.show();

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - A maioria dos clientes do banco está concentrada na faixa etária de $30$ a $34$ anos
#
#   - Isso pode indicar que o banco é mais popular entre indivíduos nessa fase da vida, que geralmente estão estabelecidos em suas carreiras e têm necessidades financeiras mais estáveis.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.4 | Distribuição de Salário dos Clientes </b></span>

# %%
# Gráfico: Distribuição de Salário dos Clientes
plt.figure(figsize=(8, 6))
sns.histplot(dados_banco['Salario'], bins=30)
plt.title('Distribuição de Salário dos Clientes')
plt.show();

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - Os salários dos clientes estão concentrados em torno de $5500$, com a maioria dos salários variando entre aproximadamente $5200$ e $5800$.
#
#   - Isso sugere que o banco atende principalmente a uma clientela de renda média.
#
#   - As Estratégias de marketing e produtos financeiros podem ser direcionados para atender às necessidades dessa faixa salarial.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.5 | Saldo em Conta Corrente e Inadimplência </b></span>

# %%
# Gráfico: Saldo em Conta Corrente e Inadimplência
plt.figure(figsize=(8, 6))
sns.boxplot(x='Inadimplente', y='Saldo_cc', data=dados_banco)
plt.title('Saldo em Conta Corrente e Inadimplência')
plt.show();

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - Os clientes inadimplentes tendem a ter saldos mais baixos em suas contas correntes em comparação com os não inadimplentes.
#
#   - Isso pode indicar que um saldo mais baixo na conta corrente pode ser um indicador de risco de inadimplência. Ou seja, isso pode ser um sinal de alerta para possíveis problemas financeiros e inadimplência.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.6 | Distribuição da Dívida no Cartão de Crédito </b></span>

# %%
# Gráfico: Distribuição da Dívida no Cartão de Crédito
plt.figure(figsize=(8, 6))
sns.histplot(dados_banco['Devedor_cartao'], bins=30)
plt.title('Distribuição da Dívida no Cartão de Crédito')
plt.show();

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - A dívida no cartão de crédito varia bastante entre os clientes, com uma concentração em torno de $2500$ a $3000$.
#
#   - Isso indica que muitos clientes têm um nível moderado de dívida no cartão
#
#   - Isso pode ser um ponto de interesse para estratégias de gestão de risco e oferta de produtos financeiros relacionados à dívida no cartão.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.7 | Relação Entre Idade e Salário </b></span>

# %%
# Gráfico: Relação Entre Idade e Salário
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Idade', y='Salario', data=dados_banco)
plt.title('Relação entre Idade e Salário')
plt.show();

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - O gráfico de dispersão mostra uma leve tendência de aumento no salário com a idade, mas essa relação não é muito forte.
#
#   - Isso pode estar acontecendo poqrque o salário dos clientes pode está sendo influenciado por outros fatores além da idade.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.8 | Distribuição de Clientes por Gênero </b></span>

# %%
# Gráfico: Distribuição de Clientes por Gênero
plt.figure(figsize=(8, 6))
sns.countplot(x='Sexo', data=dados_banco)
plt.title('Distribuição de Clientes por Gênero')
plt.show();

# %% [markdown]
#  **Conclusão**👇🏽👇👇🏽
#
# - A distribuição por gênero indica que o número de clientes masculinos e femininos é relativamente equilibrado.
#
#   - Talvez o melhor seria o banco atentar a uma base de clientes diversificada em termos de gênero.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.9 | Relação entre tipo de Emprego e Inadimplência </b></span>

# %%
# Gráfico: Relação Entre Tipo de Emprego e Inadimplência
plt.figure(figsize=(8, 6))
sns.countplot(x='Empresa', hue='Inadimplente', data=dados_banco)
plt.title('Relação entre tipo de Emprego e Inadimplência')
plt.show();

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - Parece haver alguma variação na inadimplência entre os diferentes tipos de emprego, o que pode indicar que certos segmentos profissionais enfrentam desafios financeiros distintos.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.10 | Distribuição de Saldo de Investimento </b></span>

# %%
# Gráfico: Distribuição de Saldo de Investimento
plt.figure(figsize=(8, 6))
sns.histplot(dados_banco['Saldo_investimento'], bins=30)
plt.title('Distribuição de Saldo de Investimento')
plt.show();

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - A maioria dos clientes tem pouco ou nenhum saldo em investimentos.
#   - Talvez seja uma oportunidades para o Banco promover produtos de investimento para sua base de clientes.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.11 | Perfil de Idade dos Clientes Inadimplentes </b></span>

# %%
# Gráfico: Perfil de Idade dos Clientes Inadimplentes
plt.figure(figsize=(8, 6))
sns.boxplot(x='Inadimplente', y='Idade', data=dados_banco)
plt.title('Perfil de Idade dos Clientes Inadimplentes')
plt.show();

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - A distribuição de idade entre clientes inadimplentes e não inadimplentes mostra que a inadimplência ocorre em uma ampla faixa etária, sem uma concentração clara em um grupo de idade específico.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.12 | Salário médio por tipo de empresa </b></span>

# %%
# Estabelecendo o tamanho do gráfico
plt.figure(figsize=(12,6))

# Título
plt.title("Salário Médio por tipo de Empresa")

# Gráfico de barras com salário médio por tipo de empresa
sns.barplot(x=dados_banco['Empresa'], y=dados_banco['Salario'])

# Label para eixo vertical
plt.ylabel("Salário");

# %%
# Estabelecendo o tamanho do gráfico
plt.figure(figsize=(12,6))

# Título
plt.title("Salário Médio por tipo de Empresa")

# Gráfico de barras empilhadas com salário médio por tipo de empresa
sns.barplot(x=dados_banco['Empresa'], y=dados_banco['Salario'], ci=None)

# Label para eixo vertical
plt.ylabel("Salário")

# Exibe o gráfico
plt.show();

# %% [markdown]
# **Conclusão**👇🏽👇👇🏽
#
# - Observa-se que em média a emprea Privada apresenta um salário maior.
#
#   - Estas variações podem ser diferenças no poder aquisitivo entre os clientes de diferentes categorias profissionais;
#     - Isso pode estar acontecendo porque as Empresas privadas podem oferecer salários mais altos devido à natureza do trabalho, o que pode exigir habilidades especializadas maior;
#
#   - Talvez indicando oportunidades para o banco direcionar produtos e serviços financeiros específicos que atendam melhor às necessidades de cada grupo.

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.13 | Gráfico de Dispersão </b></span>

# %%
sns.set_palette('colorblind')
sns.relplot(x='Idade', y='Salario', hue='Sexo', col='Empresa',  data=dados_banco);

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58; border-bottom: solid 3px'><b>2.8.14 | Gráficos de Regressão </b></span>

# %%
sns.lmplot(x='Idade', y='Salario', hue='Sexo', col='Empresa',  data=dados_banco);

# %%
# %%html
# <marquee style='width: 100%; color: Blue;'><b> CIENTISTA DE DADOS !</b></marquee>
# Out:
# <marquee style='width: 100%; color: Blue;'><b> CIENTISTA DE DADOS !</b></marquee>
